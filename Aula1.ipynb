# %% [markdown]
# ### Gorjetas

# %%
print('teste')
# Out:
# teste

# %%
import pandas as pd
import seaborn as sns

# %%
dataset = pd.read_csv('tips.csv')

# %%
dataset.head()
# Out:
#    total_bill   tip dessert  day    time  size
# 0       16.99  1.01      No  Sun  Dinner     2
# 1       10.34  1.66      No  Sun  Dinner     3
# 2       21.01  3.50      No  Sun  Dinner     3
# 3       23.68  3.31      No  Sun  Dinner     2
# 4       24.59  3.61      No  Sun  Dinner     4

# %%
dataset.shape
# Out:
# (244, 6)

# %% [markdown]
# ### Tradução do nome dos campos

# %%
dataset.columns
# Out:
# Index(['total_bill', 'tip', 'dessert', 'day', 'time', 'size'], dtype='object')

# %%
dataset.columns = ["valor_da_conta", "gorjeta", "sobremesa", "dia_da_semana", "hora_do_dia", "total_de_pessoas"]
dataset.head()
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01        No           Sun      Dinner
# 1           10.34     1.66        No           Sun      Dinner
# 2           21.01     3.50        No           Sun      Dinner
# 3           23.68     3.31        No           Sun      Dinner
# 4           24.59     3.61        No           Sun      Dinner
#
#    total_de_pessoas
# 0                 2
# 1                 3
# 2                 3
# 3                 2
# 4                 4

# %%
dataset.sobremesa.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
sim_nao = {"No": 'Não', 'Yes': 'Sim'}

# %%
dataset.sobremesa = dataset.sobremesa.map(sim_nao)

# %%
dataset
# Out:
#      valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0             16.99     1.01       Não           Sun      Dinner
# 1             10.34     1.66       Não           Sun      Dinner
# 2             21.01     3.50       Não           Sun      Dinner
# 3             23.68     3.31       Não           Sun      Dinner
# 4             24.59     3.61       Não           Sun      Dinner
# ..              ...      ...       ...           ...         ...
# 239           29.03     5.92       Não           Sat      Dinner
# 240           27.18     2.00       Sim           Sat      Dinner
# 241           22.67     2.00       Sim           Sat      Dinner
# 242           17.82     1.75       Não           Sat      Dinner
# 243           18.78     3.00       Não          Thur      Dinner
#
#      total_de_pessoas
# 0                   2
# 1                   3
# 2                   3
# 3                   2
# 4                   4
# ..                ...
# ...

# %%
dataset.dia_da_semana.unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
dias = {'Sun': 'Domingo', 'Sat': 'Sábado', 'Thur': 'Quinta', 'Fri': 'Sexta'}

# %%
dataset.dia_da_semana = dataset.dia_da_semana.map(dias)

# %%
dataset
# Out:
#      valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0             16.99     1.01       Não       Domingo      Dinner
# 1             10.34     1.66       Não       Domingo      Dinner
# 2             21.01     3.50       Não       Domingo      Dinner
# 3             23.68     3.31       Não       Domingo      Dinner
# 4             24.59     3.61       Não       Domingo      Dinner
# ..              ...      ...       ...           ...         ...
# 239           29.03     5.92       Não        Sábado      Dinner
# 240           27.18     2.00       Sim        Sábado      Dinner
# 241           22.67     2.00       Sim        Sábado      Dinner
# 242           17.82     1.75       Não        Sábado      Dinner
# 243           18.78     3.00       Não        Quinta      Dinner
#
#      total_de_pessoas
# 0                   2
# 1                   3
# 2                   3
# 3                   2
# 4                   4
# ..                ...
# ...

# %%
dataset.hora_do_dia.unique()
# Out:
# array(['Dinner', 'Lunch'], dtype=object)

# %%
hora = {'Dinner': 'Almoço', 'Lunch': 'Jantar'}

# %%
dataset.hora_do_dia = dataset.hora_do_dia.map(hora)
dataset
# Out:
#      valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0             16.99     1.01       Não       Domingo      Almoço
# 1             10.34     1.66       Não       Domingo      Almoço
# 2             21.01     3.50       Não       Domingo      Almoço
# 3             23.68     3.31       Não       Domingo      Almoço
# 4             24.59     3.61       Não       Domingo      Almoço
# ..              ...      ...       ...           ...         ...
# 239           29.03     5.92       Não        Sábado      Almoço
# 240           27.18     2.00       Sim        Sábado      Almoço
# 241           22.67     2.00       Sim        Sábado      Almoço
# 242           17.82     1.75       Não        Sábado      Almoço
# 243           18.78     3.00       Não        Quinta      Almoço
#
#      total_de_pessoas
# 0                   2
# 1                   3
# 2                   3
# 3                   2
# 4                   4
# ..                ...
# ...

# %% [markdown]
# ## Utilizando Seaborn

# %%
# Versão do Seaborn
sns.__version__
# Out:
# '0.11.2'

# %%
valor_gorjeta = sns.scatterplot(x='valor_da_conta', y='gorjeta', data=dataset)

# %%
dataset.shape[0]
# Out:
# 244

# %%
dataset
# Out:
#      valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0             16.99     1.01       Não       Domingo      Almoço
# 1             10.34     1.66       Não       Domingo      Almoço
# 2             21.01     3.50       Não       Domingo      Almoço
# 3             23.68     3.31       Não       Domingo      Almoço
# 4             24.59     3.61       Não       Domingo      Almoço
# ..              ...      ...       ...           ...         ...
# 239           29.03     5.92       Não        Sábado      Almoço
# 240           27.18     2.00       Sim        Sábado      Almoço
# 241           22.67     2.00       Sim        Sábado      Almoço
# 242           17.82     1.75       Não        Sábado      Almoço
# 243           18.78     3.00       Não        Quinta      Almoço
#
#      total_de_pessoas
# 0                   2
# 1                   3
# 2                   3
# 3                   2
# 4                   4
# ..                ...
# ...

# %% [markdown]
# ## Criando o campo Porcentagem da Gorjeta

# %%
dataset['pct_gorjeta'] = round((dataset['gorjeta'] / dataset['valor_da_conta']) * 100, 2)

# %%
dataset
# Out:
#      valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0             16.99     1.01       Não       Domingo      Almoço
# 1             10.34     1.66       Não       Domingo      Almoço
# 2             21.01     3.50       Não       Domingo      Almoço
# 3             23.68     3.31       Não       Domingo      Almoço
# 4             24.59     3.61       Não       Domingo      Almoço
# ..              ...      ...       ...           ...         ...
# 239           29.03     5.92       Não        Sábado      Almoço
# 240           27.18     2.00       Sim        Sábado      Almoço
# 241           22.67     2.00       Sim        Sábado      Almoço
# 242           17.82     1.75       Não        Sábado      Almoço
# 243           18.78     3.00       Não        Quinta      Almoço
#
#      total_de_pessoas  pct_gorjeta
# 0                   2         5.94
# 1                   3        16.05
# 2                   3        16.66
# 3                   2        13.98
# ...

# %%
dataset['pct_gorjeta'].describe()
# Out:
# count    244.000000
# mean      16.079754
# std        6.107020
# min        3.560000
# 25%       12.910000
# 50%       15.475000
# 75%       19.147500
# max       71.030000
# Name: pct_gorjeta, dtype: float64

# %%
porcentagem_conta = sns.scatterplot(x='valor_da_conta', y='pct_gorjeta', data=dataset)
porcentagem_conta
# Out:
# <AxesSubplot:xlabel='valor_da_conta', ylabel='pct_gorjeta'>

# %%
porcentagem_conta_linha = sns.relplot(x='valor_da_conta', y='pct_gorjeta', data=dataset)

# %%
sns.lmplot(x='valor_da_conta', y='pct_gorjeta', data=dataset)

# %%
sns.lmplot(x='valor_da_conta', y='gorjeta', data=dataset)

# %% [markdown]
# ### Análise 2 - Sobremesa

# %%
dataset.head()
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Almoço
# 1           10.34     1.66       Não       Domingo      Almoço
# 2           21.01     3.50       Não       Domingo      Almoço
# 3           23.68     3.31       Não       Domingo      Almoço
# 4           24.59     3.61       Não       Domingo      Almoço
#
#    total_de_pessoas  pct_gorjeta
# 0                 2         5.94
# 1                 3        16.05
# 2                 3        16.66
# 3                 2        13.98
# 4                 4        14.68

# %%
dataset[dataset.sobremesa == 'Sim'].describe()
# Out:
#        valor_da_conta    gorjeta  total_de_pessoas  pct_gorjeta
# count       93.000000  93.000000         93.000000    93.000000
# mean        20.756344   3.008710          2.408602    16.319140
# std          9.832154   1.401468          0.810751     8.511748
# min          3.070000   1.000000          1.000000     3.560000
# 25%         13.420000   2.000000          2.000000    10.680000
# 50%         17.920000   3.000000          2.000000    15.380000
# 75%         26.860000   3.680000          3.000000    19.510000
# max         50.810000  10.000000          5.000000    71.030000

# %%
dataset[dataset.sobremesa == 'Não'].describe()
# Out:
#        valor_da_conta     gorjeta  total_de_pessoas  pct_gorjeta
# count      151.000000  151.000000        151.000000   151.000000
# mean        19.188278    2.991854          2.668874    15.932318
# std          8.255582    1.377190          1.017984     3.990701
# min          7.250000    1.000000          1.000000     5.680000
# 25%         13.325000    2.000000          2.000000    13.690000
# 50%         17.590000    2.740000          2.000000    15.560000
# 75%         22.755000    3.505000          3.000000    18.500000
# max         48.330000    9.000000          6.000000    29.200000

# %%
sns.catplot(x='sobremesa', y='gorjeta', data=dataset)

# %%
sns.relplot(x='valor_da_conta', y='gorjeta', hue='sobremesa', data=dataset,  col='sobremesa')

# %%
sns.lmplot(x='valor_da_conta', y='gorjeta', hue='sobremesa', data=dataset,  col='sobremesa')

# %%
sns.lmplot(x='valor_da_conta', y='pct_gorjeta', hue='sobremesa', data=dataset,  col='sobremesa')

# %%
sns.relplot(x='valor_da_conta', y='pct_gorjeta', hue='sobremesa', data=dataset,  col='sobremesa', kind='line')

# %% [markdown]
# ## Teste de Hipótese

# %%
dataset.head()
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Almoço
# 1           10.34     1.66       Não       Domingo      Almoço
# 2           21.01     3.50       Não       Domingo      Almoço
# 3           23.68     3.31       Não       Domingo      Almoço
# 4           24.59     3.61       Não       Domingo      Almoço
#
#    total_de_pessoas  pct_gorjeta
# 0                 2         5.94
# 1                 3        16.05
# 2                 3        16.66
# 3                 2        13.98
# 4                 4        14.68

# %%
from scipy.stats import ranksums

# %%
sobremesa = dataset.query("sobremesa == 'Sim'").pct_gorjeta

# %%
sem_sobremesa = dataset.query("sobremesa == 'Não'").pct_gorjeta

# %%
sem_sobremesa
# Out:
# 0       5.94
# 1      16.05
# 2      16.66
# 3      13.98
# 4      14.68
#        ...
# 235    12.41
# 238    13.03
# 239    20.39
# 242     9.82
# 243    15.97
# Name: pct_gorjeta, Length: 151, dtype: float64

# %%
ranksums(sobremesa, sem_sobremesa)
# Out:
# RanksumsResult(statistic=-0.5845504113520769, pvalue=0.558850059321255)

# %% [markdown]
# ### Análise 3  - Dia da Semana

# %%
dataset.dia_da_semana.unique()
# Out:
# array(['Domingo', 'Sábado', 'Quinta', 'Sexta'], dtype=object)

# %%
sns.catplot(x='dia_da_semana', y='valor_da_conta', data=dataset)

# %%
sns.relplot(x='valor_da_conta', y='gorjeta', hue='dia_da_semana', data=dataset)

# %%
sns.relplot(x='pct_gorjeta', y='gorjeta', hue='dia_da_semana', data=dataset)

# %%
sns.relplot(x='valor_da_conta', y='gorjeta', hue='dia_da_semana', data=dataset, col='dia_da_semana')

# %%
sns.lmplot(x='valor_da_conta', y='gorjeta', hue='dia_da_semana', data=dataset, col='dia_da_semana')

# %%
media_geral_gorjetas = dataset.gorjeta.mean()
media_geral_gorjetas
# Out:
# 2.99827868852459

# %%
dataset.groupby(['dia_da_semana']).mean()
# Out:
#                valor_da_conta   gorjeta  total_de_pessoas  pct_gorjeta
# dia_da_semana
# Domingo             21.410000  3.255132          2.842105    16.689605
# Quinta              17.682742  2.771452          2.451613    16.126452
# Sexta               17.151579  2.734737          2.105263    16.991579
# Sábado              20.441379  2.993103          2.517241    15.314598

# %%
dataset.groupby(['dia_da_semana']).mean()[['valor_da_conta','gorjeta', 'pct_gorjeta']]
# Out:
#                valor_da_conta   gorjeta  pct_gorjeta
# dia_da_semana
# Domingo             21.410000  3.255132    16.689605
# Quinta              17.682742  2.771452    16.126452
# Sexta               17.151579  2.734737    16.991579
# Sábado              20.441379  2.993103    15.314598

# %%
dataset.dia_da_semana.value_counts()
# Out:
# Sábado     87
# Domingo    76
# Quinta     62
# Sexta      19
# Name: dia_da_semana, dtype: int64

# %% [markdown]
# ### Teste de Hipótese

# %%
valor_conta_domingo = dataset.query("dia_da_semana == 'Domingo'").valor_da_conta

# %%
valor_conta_sabado = dataset.query("dia_da_semana == 'Sábado'").valor_da_conta

# %%
ranksums(valor_conta_domingo, valor_conta_sabado)
# Out:
# RanksumsResult(statistic=0.9198084864360142, pvalue=0.3576728477868443)

# %% [markdown]
# ## Análise 4 - Hora do Dia

# %%
dataset.head()
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Almoço
# 1           10.34     1.66       Não       Domingo      Almoço
# 2           21.01     3.50       Não       Domingo      Almoço
# 3           23.68     3.31       Não       Domingo      Almoço
# 4           24.59     3.61       Não       Domingo      Almoço
#
#    total_de_pessoas  pct_gorjeta
# 0                 2         5.94
# 1                 3        16.05
# 2                 3        16.66
# 3                 2        13.98
# 4                 4        14.68

# %%
dataset.hora_do_dia.value_counts()
# Out:
# Almoço    176
# Jantar     68
# Name: hora_do_dia, dtype: int64

# %%
sns.catplot(x="hora_do_dia", y='valor_da_conta', data=dataset)

# %%
sns.catplot(x="hora_do_dia", y='valor_da_conta', data=dataset, kind='swarm')

# %%
sns.violinplot(x='hora_do_dia', y='valor_da_conta', data=dataset)
# Out:
# <AxesSubplot:xlabel='hora_do_dia', ylabel='valor_da_conta'>

# %%
sns.boxplot(x='hora_do_dia', y='valor_da_conta', data=dataset)
# Out:
# <AxesSubplot:xlabel='hora_do_dia', ylabel='valor_da_conta'>

# %%
almoco = dataset.query("hora_do_dia == 'Almoço'").valor_da_conta

# %%
almoco
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: valor_da_conta, Length: 176, dtype: float64

# %%
sns.displot(almoco)

# %%
sns.displot(almoco, kde=False)

# %%
jantar = dataset.query("hora_do_dia == 'Jantar'").valor_da_conta
jantar
# Out:
# 77     27.20
# 78     22.76
# 79     17.29
# 80     19.44
# 81     16.66
#        ...
# 222     8.58
# 223    15.98
# 224    13.42
# 225    16.27
# 226    10.09
# Name: valor_da_conta, Length: 68, dtype: float64

# %%
sns.displot(jantar, kde=False)

# %%
dataset.groupby(['hora_do_dia']).mean()[['valor_da_conta', 'gorjeta', 'pct_gorjeta']]
# Out:
#              valor_da_conta   gorjeta  pct_gorjeta
# hora_do_dia
# Almoço            20.797159  3.102670    15.951477
# Jantar            17.168676  2.728088    16.411765

# %%
ranksums(jantar, almoco)
# Out:
# RanksumsResult(statistic=-3.2438872807262955, pvalue=0.0011791039723641672)

# %%
pct_almoco = dataset.query("hora_do_dia == 'Almoço'")['pct_gorjeta']
pct_jantar = dataset.query("hora_do_dia == 'Jantar'")['pct_gorjeta']

# %%
ranksums(pct_almoco, pct_jantar)
# Out:
# RanksumsResult(statistic=-1.204699018193021, pvalue=0.22831951519679017)
